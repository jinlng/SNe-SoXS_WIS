# %%
from astropy.io import fits
data = fits.open('ZTF19aaadwfi_20190315_NOT_v1.fits')
data.info()
data[0].header
#print(data[0].header['DATEOBS'])
#print(data[0].header['UTSTART'])
# Out:
# Filename: ZTF19aaadwfi_20190315_NOT_v1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     215   (1873, 1, 4)   float32
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    3 / Number of axes
# NAXIS1  =                 1873 / Axis length
# NAXIS2  =                    1 / Axis length
# NAXIS3  =                    4 / Axis length
# EXTEND  =                    F / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# DATE    = '2019-03-15T10:15:13' / Date FITS file was generated
# IRAF-TLM= '2019-03-15T10:15:13' / Time of last modification
# OBJECT  = 'ZTF19aaadwfi'       / Name of the object observed
# DATE-OBS= '2019-03-15T04:12:04.638' / Start of exposure
# DATE_OBS= '2019-03-15T04:12:04.638' / Start of exposure
# OBSERVAT= 'LaPalma '
# TELESCOP= 'NOT     '
# INSTRUME= 'ALFOSC_FASU'
# ...
