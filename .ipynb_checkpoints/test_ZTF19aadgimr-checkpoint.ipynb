# %%
"""********************************************************
now it's the single-spectra objects' turn
********************************************************"""
__author__ = 'Jingyi'

print(__doc__)

import distances_conversions
import Read_data
import class_spectrum
import numpy as np
import pylab
import pdb
import pyphot
from scipy import signal
import matplotlib.pyplot as plt

filters_directory='/home/jinlng/test_dir/Type_IIn/Filters/Filters'

### ZTF19aadgimr ###
z = 0.035     # checked
linesx = {r'$H_{\alpha}$': 6563, r'$H_{\beta}$': 4861, r'$H_{\gamma}$': 4341}
    #, r'$H_{\delta}$': 4102,r'$H_{\epsilon}$': 3970, r'$H_{\zeta}$': 3889, r'$H_{\eta}$': 3835}
distance_modulus = 35.88       # checked
distance_pc = distances_conversions.DM_to_pc(distance_modulus)   # sn distance in pc
EBV = 0.016799      # checked
explosion_date = 2458491.6732986136 # checked
data_dicts = Read_data.read_data_Marshall_simple(
    '/home/jinlng/test_dir/Type_IIn/ZTF19aadgimr_data_Marshal.txt',
    filters_directory=filters_directory)

P48_r_array = np.zeros((np.shape(data_dicts['jd'][data_dicts['filter']=='r_p48'])[0],2))
P48_r_array[:,0] = data_dicts['jd'][data_dicts['filter']=='r_p48']
P48_r_array[:,1] = data_dicts['flux'][data_dicts['filter']=='r_p48']

### Calibration ###
### the only spectra ###
spec = class_spectrum.spectrum(path_to_data=
    '/home/jinlng/test_dir/Type_IIn/ZTF19aadgimr_20190204_NOT_v1.ascii',    # good to go but time unclear
    instrument='NOT',skiprows=0,time='2019-02-04T00:00:00',time_format='utc',show=False)
spec_cal = spec.calibrate(array_of_calibrating_data=P48_r_array,
    filter_family='ztf_p48',filter_name='r_p48',filters_directory=filters_directory)
spectra = [sepc]
spectra_cal = [spec_cal]

print('there are {0} spectra_cal in total'.format(len(spectra_cal)))


phases = ['+'+str(round(spectra.date_jd()-explosion_date,2)) ]
annotations = [(9300,-13.9)]

### smoothing ###
signal_smooth = signal.savgol_filter(spectra_cal[:,1],53,7)

#plot spectra
fig = plt.figure()
plt.plot(spectra[:, 0], np.log10(spectra[:, 1]),
               label=spectra.instrument + ', ' + spectra.date_utc_hms(), alpha=0.7)
# plot smoothed spectra
plt.plot(spectra_cal[:, 0], np.log10(signal_smooth), '-k', alpha=0.7)

for i,j in linesx.items():
    plt.axvline(j*(z+1),linestyle='-.',color='grey')
ax = plt.gca()
handles, labels = ax.get_legend_handles_labels()
#for i,j in enumerate(annotations):
#    ax.annotate(phases,xy = (annotations[i]))
plt.title('ZTF19aadgimr')
#pylab.ylim(-16.5,-9.7)
plt.xlim(3000,11000)
plt.ylabel(r'$\rm{log(flux [erg/sec/cm^2/\AA ])}$')
plt.xlabel(r'wavelength ($\AA$)')
plt.grid()
plt.show()
# Out:
# ********************************************************
# now it's the single-spectra objects' turn
# ********************************************************
# path is /home/jinlng/test_dir/Type_IIn/ZTF19aadgimr_data_Marshal.txt
# row is ['2018 Dec 20', '2458472.9882', 'g', '99.0', '99.0', '99.0', '19.56', 'P48+ZTF', '1', 'None', 'None', 'True']
# (12,)
# 2458472.9882
# row is ['2018 Dec 23', '2458475.9953', 'r', '99.0', '99.0', '99.0', '19.57', 'P48+ZTF', '1', 'None', 'None', 'True']
# (12,)
# 2
 'P48+ZTF', '2', 'None', 'None', 'True']
# (12,)
# 2458575.9281
# data_full[filter] is ['g' 'r' 'g' 'g' 'r' 'g' 'g' 'g' 'UVW2' 'UVW1' 'g' 'UVW2' 'UVW1' 'g' 'r'
#  'UVW2' 'UVW1' 'r' 'UVW2' 'UVW1' 'g' 'r' 'r' 'UVW2' 'UVW1' 'g' 'g' 'r' 'r'
#  'r' 'r' 'g' 'g' 'g' 'r' 'r' 'r' 'r' 'i' 'r' 'r' 'g' 'g' 'r' 'r' 'r' 'g'
#  'g' 'g' 'r' 'g' 'r' 'r' 'r' 'r' 'g' 'g' 'g' 'g' 'g' 'g' 'r' 'r' 'r' 'u'
#  'r' 'g' 'i' 'r' 'r' 'r' 'g' 'g' 'g' 'g' 'g' 'r' 'r' 'r' 'r' 'g' 'r' 'r'
#  'g' 'g' 'r' 'r' 'r' 'g' 'g' 'g' 'g' 'r' 'g' 'g' 'r' 'r' 'r' 'i' 'g' 'r'
#  'g' 'g' 'g' 'g' 'r' 'r' 'r' 'r' 'g' 'i' 'g' 'g' 'r' 'r' 'r' 'g' 'g' 'g'
#  'r' 'r' 'r' 'g' 'g' 'g' 'g' 'r' 'r' 'r' 'r']
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# UVW2
# Swift+UVOT
# ***
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# UVW1
# Swift+UVOT
# ***
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# UVW2
# Swift+UVOT
# ***
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# UVW1
# Swift+UVOT
# ***
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# UVW2
# Swift+UVOT
# ***
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# UVW1
# Swift+UVOT
# ***
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# UVW2
# Swift+UVOT
# ***
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# UVW1
# Swift+UVOT
# ***
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# UVW2
# Swift+UVOT
# ***
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# UVW1
# Swift+UVOT
# ***
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# i_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'i_p48']]
# Filter_object[0].AB_zero_flux is 1.7195294913482512e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# u_sdss
# P60+SEDM
# ***
# Filter_vector is [['sdss', 'u_sdss']]
# Filter_object[0].AB_zero_flux is 8.60948316960118e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_sdss
# P60+SEDM
# ***
# Filter_vector is [['sdss', 'r_sdss']]
# Filter_object[0].AB_zero_flux is 2.8552444744903103e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_sdss
# P60+SEDM
# ***
# Filter_vector is [['sdss', 'g_sdss']]
# Filter_object[0].AB_zero_flux is 4.923532328076015e-09 erg / angstrom * centimeter ** 2 * second
# ***
# i_sdss
# P60+SEDM
# ***
# Filter_vector is [['sdss', 'i_sdss']]
# Filter_object[0].AB_zero_flux is 1.9406782193682494e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# i_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'i_p48']]
# Filter_object[0].AB_zero_flux is 1.7195294913482512e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# i_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'i_p48']]
# Filter_object[0].AB_zero_flux is 1.7195294913482512e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# g_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'g_p48']]
# Filter_object[0].AB_zero_flux is 4.74515228722624e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# INFO:calibrate_spectrum_using_phot:output_path/txt_files did exist
# INFO:calibrate_spectrum_using_phot:calibrated_spectrum_flux_through_filter-Photometry[2]=0.0
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# ***
# r_p48
# P48+ZTF
# ***
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter_object[0].AB_zero_flux is 2.639932202863843e-09 erg / angstrom * centimeter ** 2 * second
# you provided a numpy array for the spectrum
# Library contains:  252  filters
# Filter_vector is [['ztf_p48', 'r_p48']]
# Filter: ZTF_P48_R, <pyphot.phot.Filter object at 0x7fc53fb80d68>
# Warning: assuming units are consistent
# The filter needs to be scaled up by a factor of 0.9852519867604691 in order to math the photometry
# Warning: assuming units are consistent
# there are 1659 spectra_cal in total
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-4625192b15ce> in <module>
#      54 #plot spectra
#      55 fig = plt.figure()
# ---> 56 plt.plot(spectra[:, 0], np.log10(spectra[:, 1]),
#      57                label=spectra.instrument + ', ' + spectra.date_utc_hms(), alpha=0.7)
#      58 # plot smoothed spectra
#
# TypeError: 'spectrum' object is not subscriptable

# %%
spectra = class_spectrum.spectrum(path_to_data=
    '/home/jinlng/test_dir/Type_IIn/ZTF19aadgimr_20190204_NOT_v1.ascii',    # good to go but time unclear
    instrument='NOT',skiprows=0,time='2019-02-04T00:00:00',time_format='utc',show=False)

# %%
print (spectra)
# Out:
# <class_spectrum.spectrum object at 0x7fc57c18c7b8>
